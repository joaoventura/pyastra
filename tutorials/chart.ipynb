# %%
# !pip install git+https://github.com/joaoventura/pyastra.git
# Out:
# Collecting git+https://github.com/joaoventura/pyastra.git
#   Cloning https://github.com/joaoventura/pyastra.git to /tmp/pip-req-build-ysk0otc8
#   Running command git clone --filter=blob:none --quiet https://github.com/joaoventura/pyastra.git /tmp/pip-req-build-ysk0otc8
#   Resolved https://github.com/joaoventura/pyastra.git to commit e1d1d72734d2da28e08dab4967b386b34402464f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyswisseph==2.10.3.2 (from pyastra==0.3.1)
#   Downloading pyswisseph-2.10.3.2.tar.gz (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 60.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pyastra, pyswisseph
#   Building wheel for pyastra (pyproject.toml) ... done
#   Created wheel for pyastra: filename=pyastra-0.3.1-py3-none-any.whl size=5799696 sha256=290c477aa64d46829b4ec32aae007ec75ed588e4e40fd0e906e9bf2670b73bbc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1ntyp6__/wheels/dc/51/74/d4007c16b128b72f33b7067650266d99d24911a907c04b877e
#   Building wheel for pyswisseph (setup.py) ... done
#   Created wheel for pyswisseph: filename=pyswisseph-2.10.3.2-cp312-cp312-linux_x86_64.whl size=1060519 sha256=ed6ca8b45a4f998148cb2ff6ffd8e36bfd09e3190d5de6bed26c95df36abbfca
#   Stored in directory: /root/.cache/pip/wheels/53/e8/4c/35599127e13d658763aef9a1abdf34ba927411ee29b8a06bb4
# Successfully built pyastra pyswisseph
# Installing collected packages: pyswisseph, pyastra
# Successfully installed pyastra-0.3.1 pyswisseph-2.10.3.2

# %%
from pyastra import const
from pyastra import Chart
from pyastra import Datetime
from pyastra import GeoPos


# Build a chart for a date and location
date = Datetime('2015/03/13', '17:00', '+00:00')
pos = GeoPos('38n32', '8w54')
chart = Chart(date, pos)

# Print chart
print(chart)
# Out:
# <Chart <2015/03/13 17:00:00 00:00:00> <38N32:00 08W54:00> [Alcabitus] [Tropical Zodiac]>

# %%
# Print objects and houses
print(chart.get(const.SUN))
print(chart.get(const.ASC))
# Out:
# <Sun Pisces +22:47:25 +00:59:51>
# <Asc Virgo +03:27:30>
